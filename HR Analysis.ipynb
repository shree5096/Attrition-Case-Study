# %% [markdown]
# #  HR-Employee-Attrition/Monthly Income Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
import numpy as np

# %% [markdown]
# # Reading in the input data for IBM Employee Attrition

# %%
a=pd.read_excel("/Users/user/Desktop/database/Datasets/Attrition Case Study.xlsx",sheet_name="HR-Employee-Attrition")

# %%
a.head()
# Out:
#    Attrition  Age     BusinessTravel  DailyRate              Department  \
# 0          1   41      Travel_Rarely       1102                   Sales
# 1          0   49  Travel_Frequently        279  Research & Development
# 2          1   37      Travel_Rarely       1373  Research & Development
# 3          0   33  Travel_Frequently       1392  Research & Development
# 4          0   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
a.dtypes
# Out:
# Attrition                    int64
# Age                          int64
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
a.columns
# Out:
# Index(['Attrition', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### view the important statistics like mean, standard deviation, minimum and maximum values of the 26 numeric attributes

# %%
a.describe()
# Out:
#          Attrition          Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean      0.161224    36.923810   802.485714          9.192517     2.912925
# std       0.367863     9.135373   403.509100          8.106864     1.024165
# min       0.000000    18.000000   102.000000          1.000000     1.000000
# 25%       0.000000    30.000000   465.000000          2.000000     2.000000
# 50%       0.000000    36.000000   802.000000          7.000000     3.000000
# 75%       0.000000    43.000000  1157.000000         14.000000     4.000000
# max       1.000000    60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# ...

# %% [markdown]
# ### Data Prepration

# %%
cat=[]
con=[]
for i in a.columns:
    if(a[i].dtypes=="object"):
            cat.append(i)
    else:
                con.append(i)

# %%
con
# Out:
# ['Attrition',
#  'Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
cat
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
a['Attrition'].describe()
# Out:
# count    1470.000000
# mean        0.161224
# std         0.367863
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Attrition, dtype: float64

# %%
a['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
a.Attrition.value_counts().plot(kind='bar', color="red")

# %%
a.select_dtypes(include=['object']).head()
# Out:
#       BusinessTravel              Department EducationField  Gender  \
# 0      Travel_Rarely                   Sales  Life Sciences  Female
# 1  Travel_Frequently  Research & Development  Life Sciences    Male
# 2      Travel_Rarely  Research & Development          Other    Male
# 3  Travel_Frequently  Research & Development  Life Sciences  Female
# 4      Travel_Rarely  Research & Development        Medical    Male
#
#                  JobRole MaritalStatus Over18 OverTime
# 0        Sales Executive        Single      Y      Yes
# 1     Research Scientist       Married      Y       No
# 2  Laboratory Technician        Single      Y      Yes
# 3     Research Scientist       Married      Y      Yes
# 4  Laboratory Technician       Married      Y       No

# %%
a.select_dtypes(include=['int64']).head()
# Out:
#    Attrition  Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0          1   41       1102                 1          2              1
# 1          0   49        279                 8          1              1
# 2          1   37       1373                 2          2              1
# 3          0   33       1392                 3          4              1
# 4          0   27        591                 2          1              1
#
#    EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  ...  \
# 0               1                        2          94               3  ...
# 1               2                        3          61               2  ...
# 2               4                        4          92               2  ...
# 3               5                        4          56               3  ...
# 4               7                        1          40               3  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # Exploraty data analysis

# %% [markdown]
# ### Now eplore the number of people based on different criteria to see which criteria is the dominat one for attrition

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# When examining the relationship between two variables, the first step is to classify the two relevant variables according to their role and type.
# here we use crosstad to undarstand the relationship with data

# %%
# count of people doing overtime
sb.countplot(a['OverTime'],hue=a["Attrition"])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('OverTime')
# Out:
# Text(0.5,1,'OverTime')

# %% [markdown]
# the Count of people doing overtime < the count of people not doing overtime

# %%
#count of people based on their marital status
sb.countplot(a['MaritalStatus'],hue=a["Attrition"])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Marital Status')
# Out:
# Text(0.5,1,'Marital Status')

# %%
sb.countplot(a['JobRole'],hue=a["Attrition"])
fig = plt.gcf()
fig.set_size_inches(20,15)
plt.title('Job Role')
# Out:
# Text(0.5,1,'Job Role')

# %%
#count of people based on their Gender
sb.countplot(a['Gender'],hue=a["Attrition"])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Gender')
# Out:
# Text(0.5,1,'Gender')

# %%
#count of people based on their field of education
sb.countplot(a['EducationField'],hue=a["Attrition"])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Education Field')
# Out:
# Text(0.5,1,'Education Field')

# %%
#count of people based on the department in which they work
sb.countplot(a['Department'],hue=a["Attrition"])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Department')
# Out:
# Text(0.5,1,'Department')

# %%
#count of people based on their Travel Frequency
sb.countplot(a['BusinessTravel'],hue=a["Attrition"])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Business travel')
# Out:
# Text(0.5,1,'Business travel')

# %%
#count of people based on their total working years
plt.subplots(figsize=(15,5))
sb.countplot(a.TotalWorkingYears)

# %%
#count of people based on their Education
plt.subplots(figsize=(10,5))
sb.countplot(a.Education)

# %%
#count of people based on the number of companies they have worked for
sb.countplot(a.NumCompaniesWorked)

# %%
#count of people based on the distance from home they are working
plt.subplots(figsize=(18,5))
sb.countplot(a.DistanceFromHome)

# %% [markdown]
# ## View the correlation between the actual numeric attributes

# %%
b = plt.subplots(figsize=(20, 20))
sb.heatmap(a.corr(), annot=True, linewidths=.5)

# %% [markdown]
# From the above correlation matrix we can see that Age and TotalWorkingYears are highly correlated as expected; so there should be little use in retaining both these atributes in the model. Similarly, MonthlyIncome and TotalWorkingYears seem to correlated as well, they have a correlation coefficient of about 0.7. There are other attribute pairs with higher correlation coefficient such as TotalWOrkingYears & YearsAtCompany, YearsAtCompany & YearsAtCompany, YearsInCurrentRole & YearsWithCurrManager etc. Its better not to have dependent attributes in the model if they can individually provide value to the prediction model.

# %% [markdown]
# ## Now we can plot a histogram of numeric attributes to understand the distribution.

# %%
a[con].hist(figsize=(20,20))
plt.show()

# %%
# creating a dataframe that shows values based on grouping by age
age=pd.DataFrame(a.groupby("Age")[["MonthlyIncome","Education","JobLevel","JobInvolvement","PerformanceRating","JobSatisfaction","EnvironmentSatisfaction","RelationshipSatisfaction","WorkLifeBalance","DailyRate","MonthlyRate"]].mean())
age.head()
# Out:
#      MonthlyIncome  Education  JobLevel  JobInvolvement  PerformanceRating  \
# Age
# 18     1518.375000   2.500000     1.000        2.875000           3.000000
# 19     2075.000000   2.111111     1.000        2.444444           3.444444
# 20     2539.363636   2.636364     1.000        2.636364           3.000000
# 21     2491.461538   1.615385     1.000        2.692308           3.153846
# 22     2950.000000   1.812500     1.125        2.750000           3.250000
#
#      JobSatisfaction  EnvironmentSatisfaction  RelationshipSatisfaction  \
# Age
# 18          3.250000                 2.750000                  3.125000
# 19          2.555556                 2.444444                  2.888889
# 20          2.636364                 3.181818                  2.363636
# 21          2.692308                 2.692308                  2.692308
# 22          2.937500                 2.812500                  2.250000
#
#      WorkLifeBalance   DailyRate   MonthlyRate
# Age
# ...

# %%
age["Count"]=a.Age.value_counts(dropna=False) # adding new column to age
age.reset_index(level=0, inplace=True)
age.head()
# Out:
#    Age  MonthlyIncome  Education  JobLevel  JobInvolvement  PerformanceRating  \
# 0   18    1518.375000   2.500000     1.000        2.875000           3.000000
# 1   19    2075.000000   2.111111     1.000        2.444444           3.444444
# 2   20    2539.363636   2.636364     1.000        2.636364           3.000000
# 3   21    2491.461538   1.615385     1.000        2.692308           3.153846
# 4   22    2950.000000   1.812500     1.125        2.750000           3.250000
#
#    JobSatisfaction  EnvironmentSatisfaction  RelationshipSatisfaction  \
# 0         3.250000                 2.750000                  3.125000
# 1         2.555556                 2.444444                  2.888889
# 2         2.636364                 3.181818                  2.363636
# 3         2.692308                 2.692308                  2.692308
# 4         2.937500                 2.812500                  2.250000
#
#    WorkLifeBalance   DailyRate   MonthlyRate  Count
# ...

# %%
# showing the counts for different ages
plt.figure(figsize=(15,10))
ax=sb.barplot(x=age.Age,y=age.Count)
plt.xticks(rotation=90)
plt.xlabel("Age")
plt.ylabel("Counts")
plt.title("Age Counts")
plt.show()

# %%
# showing monthly income according to age
plt.figure(figsize=(15,10))
ax=sb.barplot(x=age.Age,y=age.MonthlyIncome,palette = sb.cubehelix_palette(len(age.index)))
plt.xticks(rotation=90)
plt.xlabel("Age")
plt.ylabel("Monthly Income")
plt.title("Monthly Income According to Age")
plt.show()

# %%
# creating a dataframe called income based on the jobroles
income=pd.DataFrame(a.groupby("JobRole").MonthlyIncome.mean().sort_values(ascending=False))

# %%
# showing the job roles with their monthly incomes
plt.figure(figsize=(15,10))
ax=sb.barplot(x=income.index,y=income.MonthlyIncome)
plt.xticks(rotation=90)
plt.xlabel("Job Roles")
plt.ylabel("Monthly Income")
plt.title("Job Roles with Monthly Income")
plt.show()

# %%
# a dataframe with mean of the selected columns grouped by job role
jobrole=pd.DataFrame(a.groupby("JobRole")["PercentSalaryHike","YearsAtCompany","TotalWorkingYears","YearsInCurrentRole","WorkLifeBalance"].mean())
jobrole
# Out:
# C:\Users\user\Anaconda3.1\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                            PercentSalaryHike  YearsAtCompany  \
# JobRole
# Healthcare Representative          15.450382        8.374046
# Human Resources                    14.807692        5.326923
# Laboratory Technician              15.046332        5.019305
# Manager                            15.137255       14.431373
# Manufacturing Director             15.593103        7.600000
# Research Director                  14.950000       10.937500
# Research Scientist                 15.448630        5.113014
# Sales Executive                    14.889571        7.496933
# Sales Representative               15.674699        2.915663
#
#                            TotalWorkingYears  YearsInCurrentRole  \
# JobRole
# Healthcare Representative          14.068702            4.862595
# ...

# %% [markdown]
# ### Creating a pie chart based on the educational field.¶

# %%
labels=a.EducationField.value_counts().index
labels
# Out:
# Index(['Life Sciences', 'Medical', 'Marketing', 'Technical Degree', 'Other',
#        'Human Resources'],
#       dtype='object')

# %%
colors=["crimson","navy","orange","green","orchid","rosybrown"]
sizes=a.EducationField.value_counts().values
sizes
explode = (0,0,0,0.1,0.1,0.1)

# %%
plt.figure(figsize=(10,10))
plt.pie(sizes,labels=labels,colors=colors,autopct='%1.1f%%',explode=explode)
plt.title("Education Field Counts",color="saddlebrown",fontsize=15)
# Out:
# Text(0.5,1,'Education Field Counts')

# %% [markdown]
# ### All the exploratory data analysis above shall help the HR team to find a pattern or find and filter the criteria which are most reponsible for attrition.

# %%
a=pd.get_dummies(a)

# %%
a.head()

# %%
x=a.drop(["Attrition"],axis=1)
y=y=a[["Attrition"]]
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x=scale.fit_transform(x)

# %% [markdown]
# the above attributes are converted to categoric data type into contineous data type.

# %% [markdown]
# # using Linear Regression

# %%
for i in range(10,100,10):
    x=a.drop(["Attrition"],axis=1)
    y=a[["Attrition"]]

    from sklearn.model_selection import train_test_split
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=i)

    from sklearn.linear_model import LinearRegression
    lm=LinearRegression()
    model=lm.fit(xtrain,ytrain)
    pred=model.predict(xtest)

    from sklearn.metrics import mean_absolute_error
    print("MAE for linear model is %2f"%(mean_absolute_error(ytest,pred)))

# %%
model.score(xtrain,ytrain)

# %%
x=a.drop(["Attrition"],axis=1)
y=a[['Attrition']]
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=i)

from statsmodels.api import OLS,add_constant
xconst=add_constant(xtrain)
est=OLS(ytrain,xconst)
est2=est.fit()
print(est2.summary())

# %% [markdown]
# some of the attributes have P value less than 0.05.

# %%
    from sklearn import metrics
    print('Mean Absolute Error:',metrics.mean_absolute_error(ytest,pred))
    print('Mean Squared Error:',metrics.mean_squared_error(ytest,pred))
    print('Root Mean Squared Error:',np.sqrt(metrics.mean_squared_error(ytest,pred)))

# %% [markdown]
# # Using Logistic Regression

# %%
x=a.drop(["Attrition"],axis=1)
y=a['Attrition']
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.20,random_state=0)
    
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
model = lr.fit(xtrain,ytrain)
pred = model.predict(xtest)

from sklearn.metrics import confusion_matrix,accuracy_score
cnf_matrix=(confusion_matrix(ytest,pred))
cnf_matrix
print(accuracy_score(ytest,pred))
print(confusion_matrix(ytest,pred))

# %%
sb.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')

# %% [markdown]
# There are 263 observations in the test data set. Among the 240 observations with ‘No’ for Attrition, 5 are predicted incorrectly. Among the 26 observations with ‘Yes’ value for Attrition, 23 are predicted incorrectly

# %%
import sklearn.metrics as m
probs = lr.predict_proba(xtest)
preds = probs[:,1]
fpr,tpr,threshold=m.roc_curve(ytest,preds)
roc_auc=m.auc(fpr,tpr)

# %%
plt.plot(fpr,tpr,roc_auc)

# %%
from sklearn.metrics import classification_report 
print(classification_report(ytest,pred))

# %% [markdown]
# Higher value of the above metrics for observations with ‘No’ value for Attrition is due to imbalance in the dataset.

# %%
x=a.drop(["Attrition"],axis=1)
y=a['Attrition']
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=30)

from sklearn.tree import DecisionTreeClassifier
dc=DecisionTreeClassifier(criterion='entropy',random_state=20,max_depth=3)
model=dc.fit(xtrain,ytrain)
pred=model.predict(xtest)

from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest,pred)*100

from sklearn.metrics import confusion_matrix,accuracy_score
confusion_matrix(ytest,pred)
accuracy_score(ytest,pred)*100

# %%
x=a.drop(["Attrition"],axis=1)
y=a['Attrition']
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=30)
from sklearn.ensemble import RandomForestClassifier
rfc= RandomForestClassifier(random_state=20,max_leaf_nodes=8,criterion='entropy')
model=rfc.fit(xtrain,ytrain)
pred=model.predict(xtest)
from sklearn.metrics import accuracy_score
print("accuracy is %f"%(accuracy_score(ytest,pred)*100))

# %%
x=a.drop(["Attrition"],axis=1)
y=a['Attrition']
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=20)


from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
abc=AdaBoostClassifier(DecisionTreeClassifier(max_depth=2),n_estimators=20)
model=abc.fit(xtrain,ytrain)
pred=model.predict(xtest)

# %%
ytest["pred"]=pred

# %%
ytest

# %%
model.score(xtrain,ytrain)*100

# %%
model.feature_importances_

# %%
plt.subplots(figsize=(10,10))
plt.barh(x.columns,model.feature_importances_,color="g")

# %%
x.columns

# %%
W=pd.DataFrame(zip(x.columns, model.feature_importances_), columns=["columns", "importance"])

# %%
W

# %%
W=W.sort_values(by="importance")

# %%
b = plt.subplots(figsize=(20,20))
plt.barh(x.columns, W.importance,color="g")

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=20)


from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
abc=GradientBoostingClassifier(loss='deviance',learning_rate=0.15,n_estimators=50,max_depth=4)
model=abc.fit(xtrain,ytrain)
pred2=model.predict(xtest)

# %%
from sklearn.model_selection import GridSearchCV
tp={"max_depth":range(2,20),"learning_rate":[0.15,0.1,0.10,0.05]}
abc1=GradientBoostingClassifier()
cv=GridSearchCV(abc,tp,scoring="accuracy")
cvmodel=cv.fit(xtrain,ytrain)

# %%
cv.best_params_

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cnf=confusion_matrix(ytest,pred2)
accuracy_score(ytest,pred2)*100

# %%
cnf

# %%
import xgboost
classifier = xgboost.XGBClassifier(objective='reg:logistic', booster='gbtree',random_state=20,colsample_bytree = 0.3,learning_rate = 0.1,max_depth = 5, alpha = 10, n_estimators = 50)
classifier.fit(xtrain, ytrain)

# %%
ypred = classifier.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(ytest, ypred)
accuracy_score(ytest,ypred)*100

# %%
cm
